# %%
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath('..'))
from generators import get_generator, DataSet, comp_datasets_meta, comp_datasets

folder_path = '../data'
config_path = '../configs'

# %%
seed = 42
n = 200
names = ['pd_ms','bl_ms','gp','rw']

# %%
for name in names:
    print(name)
    generator = get_generator(name,seed,config_path)
    generator.save_signals(n,folder_path)
# Out:
# pd_ms
# bl_ms
# gp
# /home/solt/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /home/solt/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /home/solt/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
dataset = DataSet('rw',seed,n,folder_path)

dataset.print_summary()

_, ax = plt.subplots(1,figsize=(9,3),dpi=100)
dataset.plot_samples(ax=ax,num_samples=5)
plt.show()
# Out:
# Data path: ../data/rw_42_200.npy
# # of sequencnes: 200
#
# Lengths:
# 	* Min: 150
# 	* Max: 150
# 	* Mean : 150.00
# 	* Std: 0.00
#
# Data:
# 	* Min: -0.20
# 	* Max: 0.23
# 	* Mean : 0.00
# 	* Std: 0.06

# %%
data_sets  = [DataSet('pd_ms',None,200,folder_path)]
data_sets += [DataSet(name,seed,n,folder_path) for name in names]
comp_datasets_meta(data_sets)

# %%
comp_datasets(data_sets,num_samples=10)
